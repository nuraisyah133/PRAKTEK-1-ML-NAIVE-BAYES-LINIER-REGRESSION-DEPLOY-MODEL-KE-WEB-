# %% [markdown]
# **NUR AISYAH (NIM. 1217070060) - Machine Learning (B)**

# %% [markdown]
# # **Latihan 3 : Study Kasus Deployment Model Machine Learning Pada Web Untuk Prediksi Keuntungan Star-Up Berdasarkan Pengaluaran Menggunakan Flash**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'


df = pd.read_csv(url)

print(f"Data berisi {df.shape[0]} baris dan {df.shape[1]} kolom.\nDengan pratinjau 5 sampel sebagai berikut:\n")
print(df.head())
# Out:
# Data berisi 50 baris dan 5 kolom.
# Dengan pratinjau 5 sampel sebagai berikut:
#
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

# URL file
url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'

# Membaca data dari URL
df = pd.read_csv(url)

X = df.iloc[:, :-2].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

X
# Out:
# array([[165349.2 , 136897.8 , 471784.1 ],
#        [162597.7 , 151377.59, 443898.53],
#        [153441.51, 101145.55, 407934.54],
#        [144372.41, 118671.85, 383199.62],
#        [142107.34,  91391.77, 366168.42],
#        [131876.9 ,  99814.71, 362861.36],
#        [134615.46, 147198.87, 127716.82],
#        [130298.13, 145530.06, 323876.68],
#        [120542.52, 148718.95, 311613.29],
#        [123334.88, 108679.17, 304981.62],
#        [101913.08, 110594.11, 229160.95],
#        [100671.96,  91790.61, 249744.55],
#        [ 93863.75, 127320.38, 249839.44],
#        [ 91992.39, 135495.07, 252664.93],
#        [119943.24, 156547.42, 256512.92],
#        [114523.61, 122616.84, 261776.23],
#        [ 78013.11, 121597.55, 264346.06],
#        [ 94657.16, 145077.58, 282574.31],
#        [ 91749.16, 114175.79, 294919.57],
#        [ 86419.7 , 153514.11,      0.  ],
#        [ 76253.86, 113867.3 , 298664.47],
#        [ 78389.47, 153773.43, 299737.29],
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

# URL file
url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'

# Membaca data dari URL
df = pd.read_csv(url)

X = df.iloc[:, :-2].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

X

regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

# URL file
url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'

# Membaca data dari URL
df = pd.read_csv(url)

X = df.iloc[:, :-2].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

X

regression = LinearRegression()
regression.fit(X_train, y_train)

y_pred = regression.predict(X_test)

mean_absolute_error(y_test, y_pred)
# Out:
# 8573.801944370189

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

# URL file
url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'

# Membaca data dari URL
df = pd.read_csv(url)

X = df.iloc[:, :-2].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

X

regression = LinearRegression()
regression.fit(X_train, y_train)

y_pred = regression.predict(X_test)

mean_absolute_error(y_test, y_pred)
joblib.dump(regression, "hasil_pelatihan_model.pkl")
# Out:
# ['hasil_pelatihan_model.pkl']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
import joblib

# URL file
url = '/content/drive/MyDrive/NUR AISYAH, S.T/Semesters/SEMESTER 7/Machine Learning/PRAKTEK 1 ML ( NAIVE BAYES, LINIER REGRESSION, DEPLOY MODEL KE WEB)/sample_data.csv'

# Membaca data dari URL
df = pd.read_csv(url)

X = df.iloc[:, :-2].values
y = df.iloc[:, -1].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

X

regression = LinearRegression()
regression.fit(X_train, y_train)

y_pred = regression.predict(X_test)

mean_absolute_error(y_test, y_pred)
joblib.dump(regression, "hasil_pelatihan_model.pkl")

RnD_Spend = 0
Administration_Spend = 20
Marketing_Spend = 3
pred_args = [RnD_Spend,Administration_Spend,Marketing_Spend]
pred_args_arr = np.array(pred_args)
pred_args_arr = pred_args_arr.reshape(1, -1)
mul_reg = open("hasil_pelatihan_model.pkl","rb")
ml_model = joblib.load(mul_reg)
model_prediction = ml_model.predict(pred_args_arr)

print(f'Prediksi profit yang didapatkan adalah... ${round(float(model_prediction), 2)}')
# Out:
# Prediksi profit yang didapatkan adalah... $49027.7
# <ipython-input-16-9f501bb25f14>:42: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f'Prediksi profit yang didapatkan adalah... ${round(float(model_prediction), 2)}')
